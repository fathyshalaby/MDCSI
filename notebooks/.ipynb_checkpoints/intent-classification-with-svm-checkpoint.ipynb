# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.metrics import balanced_accuracy_score

# %% [markdown]
# # **Intent Classification**
#
# Intent classification (sometimes called intent recognition) is a technique used in natural language processing (NLP). Intent classification analyzes the intentions behind texts and categorizes them.
#
# Some of the common techniques for intent classification are regex and machine learning algorithms.
#
# This project will use labelled data from Airline Travel Information System with customer queries and intents as labels. We will use a supervised learning method Support Vector Machines (SVMs).
#
# ![](https://miro.medium.com/max/1400/1*CadlfKHwHualA9od3SM-ew.png)

# %% [markdown]
# # **EDA**

# %%
# load data and print first 10 rows
def load_data(path):
    df = pd.read_csv(path)
    df.columns = ['label', 'query']
    return df

df = load_data(os.path.join('..','data','external','atis-intent','atis_intents_test.csv'))
df.to_csv(os.path.join('..','data','external','atis-intent','atis_intents_test_.csv'))

# %%
# print shape of our data
print("There are {} rows and {} columns".format(df.shape[0], df.shape[1]))
# Out:
# There are 799 rows and 2 columns

# %%
# explore unique labels
print(df.label.unique())
# Out:
# ['atis_airfare' 'atis_flight' 'atis_ground_service' 'atis_airline'
#  'atis_flight_time' 'atis_quantity' 'atis_abbreviation' 'atis_aircraft']

# %%
# explore which labels are the most and least common
df.label.value_counts()
# Out:
# atis_flight            631
# atis_airfare            48
# atis_airline            38
# atis_ground_service     36
# atis_abbreviation       33
# atis_aircraft            9
# atis_quantity            3
# atis_flight_time         1
# Name: label, dtype: int64

# %%
# drop rows with multiple labels
df = df[df["label"].str.contains("#")==False]
df.label.value_counts()
# Out:
# atis_flight            631
# atis_airfare            48
# atis_airline            38
# atis_ground_service     36
# atis_abbreviation       33
# atis_aircraft            9
# atis_quantity            3
# atis_flight_time         1
# Name: label, dtype: int64

# %% [markdown]
# # **Preprocessing**

# %%
# !pip install spacy
# !pip install markupsafe==2.0.1 --user
# !python -m spacy download en_core_web_lg
# Out:
# Collecting spacy
#   Downloading spacy-3.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 27.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy) (2.28.1)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.7-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy) (59.5.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4
#   Downloading pydantic-1.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 29.7 MB/s eta 0:00:0000:0100:01
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Requirement already satisfied: packaging>=20.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy) (21.3)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35 kB)
# Collecting pathy>=0.3.5
#   Using cached pathy-0.6.2-py3-none-any.whl (42 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Using cached typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.3-py3-none-any.whl (9.3 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.10-py2.py3-none-any.whl (21 kB)
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy>=1.15.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy) (1.23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy) (4.64.1)
# Collecting thinc<8.2.0,>=8.1.0
#   Downloading thinc-8.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (813 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy) (3.1.2)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.8-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.5/459.5 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.9)
# Collecting smart-open<6.0.0,>=5.2.1
#   Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy) (4.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.1-py3-none-any.whl (32 kB)
# Collecting blis<0.10.0,>=0.7.8
#   Downloading blis-0.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 24.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fathy/.local/lib/python3.9/site-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: wasabi, cymem, typer, spacy-loggers, spacy-legacy, smart-open, pydantic, murmurhash, langcodes, catalogue, blis, srsly, preshed, pathy, confection, thinc, spacy
# Successfully installed blis-0.9.1 catalogue-2.0.8 confection-0.0.1 cymem-2.0.6 langcodes-3.3.0 murmurhash-1.0.8 pathy-0.6.2 preshed-3.0.7 pydantic-1.9.2 smart-open-5.2.1 spacy-3.4.1 spacy-legacy-3.0.10 spacy-loggers-1.0.3 srsly-2.4.4 thinc-8.1.1 typer-0.4.2 wasabi-0.10.1
# Requirement already satisfied: markupsafe==2.0.1 in /home/fathy/.local/lib/python3.9/site-packages (2.0.1)
# Collecting en-core-web-lg==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.0/en_core_web_lg-3.4.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 479.6 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from en-core-web-lg==3.4.0) (3.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.28.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.10.1)
# Requirement already satisfied: setuptools in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (59.5.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.23.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.6.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.9.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.0.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (21.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (8.1.1)
# Requirement already satisfied: jinja2 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.4.4)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.4.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2022.9.14)
# Requirement already satisfied: blis<0.10.0,>=0.7.8 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.9.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.0.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fathy/.local/lib/python3.9/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.0.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.4.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# import libraries and load spacy English model
import spacy
import numpy as np

nlp = spacy.load("en_core_web_lg")
print("Number of vectors: {}".format(nlp.vocab.vectors_length))
# Out:
# Number of vectors: 300

# %%
# load training and test datasets
training_df = load_data(os.path.join('..','data','external','atis-intent','atis_intents_train.csv'))
training_df = training_df[training_df["label"].str.contains("#")==False]

sen_train = training_df['query'].tolist()
labels_train = training_df['label'].tolist()

test_df = load_data(os.path.join('..','data','external','atis-intent','atis_intents_test.csv'))
test_df = test_df[test_df["label"].str.contains("#")==False]
sen_test = test_df['query'].tolist()
labels_test = test_df['label'].tolist()

# %%
train_size = len(labels_train)
test_size = len(labels_test)


print('Train data has {} rows and test data has {} rows'.format(train_size, test_size))
# Out:
# Train data has 4833 rows and test data has 799 rows

# %%
def encode_sentences(sentences):
    # Calculate number of sentences
    n_sentences = len(sentences)
    X = np.zeros((n_sentences, 300))

    # Iterate over the sentences
    for idx, sentence in enumerate(sentences):
        # Pass each sentence to the nlp object to create a document
        doc = nlp(sentence)
        # Save the document's .vector attribute to the corresponding row in     
        # X
        X[idx, :] = doc.vector
    return X

train_X = encode_sentences(sen_train)
test_X = encode_sentences(sen_test)

# %% [markdown]
# ## Visulize the encodings

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (1.1.2)
# Requirement already satisfied: joblib>=1.0.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from scikit-learn) (1.23.1)
# Requirement already satisfied: scipy>=1.3.2 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from scikit-learn) (1.9.1)

# %%
from sklearn.manifold import TSNE
import re


X = train_X
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)
# Out:
# /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
df = pd.DataFrame(X_tsne, index=sen_train, columns=['x', 'y'])
df["sentence"]=sen_train
df["intent"]= labels_train

# %%
# !pip install altair
# Out:
# Collecting altair
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 15.8 MB/s eta 0:00:00a 0:00:01
# Collecting toolz
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from altair) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from altair) (4.16.0)
# Requirement already satisfied: pandas>=0.18 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from altair) (1.5.0)
# Requirement already satisfied: numpy in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from altair) (1.23.1)
# Requirement already satisfied: entrypoints in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from altair) (0.4)
# Requirement already satisfied: attrs>=17.4.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (0.18.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from pandas>=0.18->altair) (2022.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fathy/.local/lib/python3.9/site-packages (from jinja2->altair) (2.0.1)
# Requirement already satisfied: six>=1.5 in /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)
# Installing collected packages: toolz, altair
# Successfully installed altair-4.2.0 toolz-0.12.0

# %%
import altair as alt
alt.Chart(df).mark_circle(size=60).encode(
    x='x',
    y='y',
    color='intent',
    tooltip=['sentence']
).interactive()
# Out:
# /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %% [markdown]
# # **Label Encoding**

# %%
# encode labels i.e turn text labels into integers
from sklearn.preprocessing import LabelEncoder

# instantiate label encoder object
le = LabelEncoder()

labels_test = le.fit_transform(labels_test)
labels_train = le.fit_transform(labels_train)

# %%
# !pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.9-py2.py3-none-any.whl (12 kB)
# Collecting pytest==5.4.3
#   Downloading pytest-5.4.3-py3-none-any.whl (248 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.1/248.1 kB 12.1 MB/s eta 0:00:00
# Collecting xgboost==1.1.1
#   Downloading xgboost-1.1.1-py3-none-manylinux2010_x86_64.whl (127.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.6/127.6 MB 2.7 MB/s eta 0:00:0000:0100:01
# Collecting six==1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting pandas==1.0.5
#   Downloading pandas-1.0.5.tar.gz (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 29.1 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [336 lines of output]
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#       Collecting setuptools
#         Downloading setuptools-65.3.0-py3-none-any.whl (1.2 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.1 MB/s eta 0:00:00
#       Collecting wheel
#         Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#       Collecting Cython>=0.29.13
#         Downloading Cython-0.29.32-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (2.0 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 29.7 MB/s eta 0:00:00
#       Collecting numpy==1.17.3
#         Downloading numpy-1.17.3.zip (6.4 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 31.1 MB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Building wheels for collected packages: numpy
#         Building wheel for numpy (setup.py): started
#         Building wheel for numpy (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [128 lines of output]
#             Running from numpy source directory.
#             blas_opt_info:
#             blas_mkl_info:
#             customize UnixCCompiler
#               FOUND:
#                 libraries = ['mkl_rt', 'pthread']
#                 library_dirs = ['/home/fathy/anaconda3/envs/intent/lib']
#                 define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#                 include_dirs = ['/usr/local/include', '/usr/include', '/home/fathy/anaconda3/envs/intent/include']
#
#               FOUND:
#                 libraries = ['mkl_rt', 'pthread']
#                 library_dirs = ['/home/fathy/anaconda3/envs/intent/lib']
#                 define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#                 include_dirs = ['/usr/local/include', '/usr/include', '/home/fathy/anaconda3/envs/intent/include']
#
#             /bin/sh: 1: svnversion: not found
#             non-existing path in 'numpy/distutils': 'site.cfg'
#             lapack_opt_info:
#             lapack_mkl_info:
#             customize UnixCCompiler
#               FOUND:
#                 libraries = ['mkl_rt', 'pthread']
#                 library_dirs = ['/home/fathy/anaconda3/envs/intent/lib']
#                 define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#                 include_dirs = ['/usr/local/include', '/usr/include', '/home/fathy/anaconda3/envs/intent/include']
#
#               FOUND:
#                 libraries = ['mkl_rt', 'pthread']
#                 library_dirs = ['/home/fathy/anaconda3/envs/intent/lib']
#                 define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#                 include_dirs = ['/usr/local/include', '/usr/include', '/home/fathy/anaconda3/envs/intent/include']
#
#             /home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#               warnings.warn(msg)
#             running bdist_wheel
#             running build
#             running config_cc
#             unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#             running config_fc
#             unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#             running build_src
#             build_src
#             building py_modules sources
#             creating build
#             creating build/src.linux-x86_64-3.9
#             creating build/src.linux-x86_64-3.9/numpy
#             creating build/src.linux-x86_64-3.9/numpy/distutils
#             building library "npymath" sources
#             get_default_fcompiler: matching types: '['gnu95', 'intel', 'lahey', 'pg', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor']'
#             customize Gnu95FCompiler
#             Could not locate executable gfortran
#             Could not locate executable f95
#             customize IntelFCompiler
#             Could not locate executable ifort
#             Could not locate executable ifc
#             customize LaheyFCompiler
#             Could not locate executable lf95
#             customize PGroupFCompiler
#             Could not locate executable pgfortran
#             customize AbsoftFCompiler
#             Could not locate executable f90
#             Could not locate executable f77
#             customize NAGFCompiler
#             customize VastFCompiler
#             customize CompaqFCompiler
#             Could not locate executable fort
#             customize IntelItaniumFCompiler
#             Could not locate executable efort
#             Could not locate executable efc
#             customize IntelEM64TFCompiler
#             customize GnuFCompiler
#             Could not locate executable g77
#             customize G95FCompiler
#             Could not locate executable g95
#             customize PathScaleFCompiler
#             Could not locate executable pathf95
#             customize NAGFORCompiler
#             Could not locate executable nagfor
#             don't know how to compile Fortran code on platform 'posix'
#             C compiler: gcc -pthread -B /home/fathy/anaconda3/envs/intent/compiler_compat -Wl,--sysroot=/ -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/fathy/anaconda3/envs/intent/include -fPIC -O2 -isystem /home/fathy/anaconda3/envs/intent/include -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/fathy/anaconda3/envs/intent/include/python3.9 -c'
#             gcc: _configtest.c
#             failure.
#             removing: _configtest.c _configtest.o
#             Traceback (most recent call last):
#               File "<string>", line 2, in <module>
#               File "<pip-setuptools-caller>", line 34, in <module>
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/setup.py", line 443, in <module>
#                 setup_package()
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/setup.py", line 435, in setup_package
#                 setup(**metadata)
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/core.py", line 171, in setup
#                 return old_setup(**new_attr)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages/setuptools/__init__.py", line 153, in setup
#                 return distutils.core.setup(**attrs)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/core.py", line 148, in setup
#                 dist.run_commands()
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/dist.py", line 966, in run_commands
#                 self.run_command(cmd)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/dist.py", line 985, in run_command
#                 cmd_obj.run()
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages/wheel/bdist_wheel.py", line 299, in run
#                 self.run_command('build')
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/cmd.py", line 313, in run_command
#                 self.distribution.run_command(command)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/dist.py", line 985, in run_command
#                 cmd_obj.run()
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/build.py", line 47, in run
#                 old_build.run(self)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/command/build.py", line 135, in run
#                 self.run_command(cmd_name)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/cmd.py", line 313, in run_command
#                 self.distribution.run_command(command)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/dist.py", line 985, in run_command
#                 cmd_obj.run()
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/build_src.py", line 142, in run
#                 self.build_sources()
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/build_src.py", line 153, in build_sources
#                 self.build_library_sources(*libname_info)
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/build_src.py", line 286, in build_library_sources
#                 sources = self.generate_sources(sources, (lib_name, build_info))
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/build_src.py", line 369, in generate_sources
#                 source = func(extension, build_dir)
#               File "numpy/core/setup.py", line 669, in get_mathlib_info
#                 raise RuntimeError("Broken toolchain: cannot link a simple C program")
#             RuntimeError: Broken toolchain: cannot link a simple C program
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for numpy
#         Running setup.py clean for numpy
#         error: subprocess-exited-with-error
#
#         × python setup.py clean did not run successfully.
#         │ exit code: 1
#         ╰─> [10 lines of output]
#             Running from numpy source directory.
#
#             `setup.py clean` is not supported, use one of the following instead:
#
#               - `git clean -xdf` (cleans all files)
#               - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                                   files that aren't checked into the git repo)
#
#             Add `--force` to your command to use it anyway if you must (unsupported).
#
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed cleaning build dir for numpy
#       Failed to build numpy
#       Installing collected packages: wheel, setuptools, numpy, Cython
#         Running setup.py install for numpy: started
#         Running setup.py install for numpy: finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Running setup.py install for numpy did not run successfully.
#         │ exit code: 1
#         ╰─> [139 lines of output]
#             Running from numpy source directory.
#
#             Note: if you need reliable uninstall behavior, then install
#             with pip instead of using `setup.py install`:
#
#               - `pip install .`       (from a git repo or downloaded source
#                                        release)
#               - `pip install numpy`   (last NumPy release on PyPi)
#
#
#             blas_opt_info:
#             blas_mkl_info:
#             customize UnixCCompiler
#               FOUND:
#                 libraries = ['mkl_rt', 'pthread']
#                 library_dirs = ['/home/fathy/anaconda3/envs/intent/lib']
#                 define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#                 include_dirs = ['/usr/local/include', '/usr/include', '/home/fathy/anaconda3/envs/intent/include']
#
#               FOUND:
#                 libraries = ['mkl_rt', 'pthread']
#                 library_dirs = ['/home/fathy/anaconda3/envs/intent/lib']
#                 define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#                 include_dirs = ['/usr/local/include', '/usr/include', '/home/fathy/anaconda3/envs/intent/include']
#
#             /bin/sh: 1: svnversion: not found
#             non-existing path in 'numpy/distutils': 'site.cfg'
#             lapack_opt_info:
#             lapack_mkl_info:
#             customize UnixCCompiler
#               FOUND:
#                 libraries = ['mkl_rt', 'pthread']
#                 library_dirs = ['/home/fathy/anaconda3/envs/intent/lib']
#                 define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#                 include_dirs = ['/usr/local/include', '/usr/include', '/home/fathy/anaconda3/envs/intent/include']
#
#               FOUND:
#                 libraries = ['mkl_rt', 'pthread']
#                 library_dirs = ['/home/fathy/anaconda3/envs/intent/lib']
#                 define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#                 include_dirs = ['/usr/local/include', '/usr/include', '/home/fathy/anaconda3/envs/intent/include']
#
#             /home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#               warnings.warn(msg)
#             running install
#             /home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#               warnings.warn(
#             running build
#             running config_cc
#             unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#             running config_fc
#             unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#             running build_src
#             build_src
#             building py_modules sources
#             building library "npymath" sources
#             get_default_fcompiler: matching types: '['gnu95', 'intel', 'lahey', 'pg', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor']'
#             customize Gnu95FCompiler
#             Could not locate executable gfortran
#             Could not locate executable f95
#             customize IntelFCompiler
#             Could not locate executable ifort
#             Could not locate executable ifc
#             customize LaheyFCompiler
#             Could not locate executable lf95
#             customize PGroupFCompiler
#             Could not locate executable pgfortran
#             customize AbsoftFCompiler
#             Could not locate executable f90
#             Could not locate executable f77
#             customize NAGFCompiler
#             customize VastFCompiler
#             customize CompaqFCompiler
#             Could not locate executable fort
#             customize IntelItaniumFCompiler
#             Could not locate executable efort
#             Could not locate executable efc
#             customize IntelEM64TFCompiler
#             customize GnuFCompiler
#             Could not locate executable g77
#             customize G95FCompiler
#             Could not locate executable g95
#             customize PathScaleFCompiler
#             Could not locate executable pathf95
#             customize NAGFORCompiler
#             Could not locate executable nagfor
#             don't know how to compile Fortran code on platform 'posix'
#             C compiler: gcc -pthread -B /home/fathy/anaconda3/envs/intent/compiler_compat -Wl,--sysroot=/ -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/fathy/anaconda3/envs/intent/include -fPIC -O2 -isystem /home/fathy/anaconda3/envs/intent/include -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/fathy/anaconda3/envs/intent/include/python3.9 -c'
#             gcc: _configtest.c
#             failure.
#             removing: _configtest.c _configtest.o
#             Traceback (most recent call last):
#               File "<string>", line 2, in <module>
#               File "<pip-setuptools-caller>", line 34, in <module>
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/setup.py", line 443, in <module>
#                 setup_package()
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/setup.py", line 435, in setup_package
#                 setup(**metadata)
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/core.py", line 171, in setup
#                 return old_setup(**new_attr)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/site-packages/setuptools/__init__.py", line 153, in setup
#                 return distutils.core.setup(**attrs)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/core.py", line 148, in setup
#                 dist.run_commands()
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/dist.py", line 966, in run_commands
#                 self.run_command(cmd)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/dist.py", line 985, in run_command
#                 cmd_obj.run()
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/install.py", line 62, in run
#                 r = self.setuptools_run()
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/install.py", line 36, in setuptools_run
#                 return distutils_install.run(self)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/command/install.py", line 546, in run
#                 self.run_command('build')
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/cmd.py", line 313, in run_command
#                 self.distribution.run_command(command)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/dist.py", line 985, in run_command
#                 cmd_obj.run()
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/build.py", line 47, in run
#                 old_build.run(self)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/command/build.py", line 135, in run
#                 self.run_command(cmd_name)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/cmd.py", line 313, in run_command
#                 self.distribution.run_command(command)
#               File "/home/fathy/anaconda3/envs/intent/lib/python3.9/distutils/dist.py", line 985, in run_command
#                 cmd_obj.run()
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/build_src.py", line 142, in run
#                 self.build_sources()
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/build_src.py", line 153, in build_sources
#                 self.build_library_sources(*libname_info)
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/build_src.py", line 286, in build_library_sources
#                 sources = self.generate_sources(sources, (lib_name, build_info))
#               File "/tmp/pip-install-_ss43fv2/numpy_be132915893a4016982a0207694c5365/numpy/distutils/command/build_src.py", line 369, in generate_sources
#                 source = func(extension, build_dir)
#               File "numpy/core/setup.py", line 669, in get_mathlib_info
#                 raise RuntimeError("Broken toolchain: cannot link a simple C program")
#             RuntimeError: Broken toolchain: cannot link a simple C program
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: legacy-install-failure
#
#       × Encountered error while trying to install package.
#       ╰─> numpy
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for output from the failure.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
#       2 models,predictions = clf.fit(X_train, X_test, y_train, y_test)
#       4 print(models)
#
# NameError: name 'LazyClassifier' is not defined

# %% [markdown]
# # **Intent classification with SVM**

# %%
# Import SVC
from sklearn.svm import SVC
# Train the model
clfs = SVC(C=1)
clfs.fit(train_X, labels_train)

# %%
print('Validation on the train set results:')
balanced_accuracy_score(labels_train,clf.predict(train_X))

# %%
# Validate model on test set
print('Validation on the test set results:')
balanced_accuracy_score(labels_test,clf.predict(test_X))

# %% [markdown]
# Model accuracy on test set is 1% higher than on train set most likely due to the small size of test set.
